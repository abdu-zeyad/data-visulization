# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
sns.set()

# %%
df_corona = pd.read_csv('covid_inida.csv')
df_corona.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   State/UTs            36 non-null     object
#  1   Total Cases          36 non-null     int64
#  2   Active               36 non-null     int64
#  3   Discharged           36 non-null     int64
#  4   Deaths               36 non-null     int64
#  5   Active Ratio (%)     36 non-null     float64
#  6   Discharge Ratio (%)  36 non-null     float64
#  7   Death Ratio (%)      36 non-null     float64
# dtypes: float64(3), int64(4), object(1)
# memory usage: 2.4+ KB

# %%
sns.lmplot(x='Total Cases', y='Active', data=df_corona, line_kws={'color': 'red'}, scatter_kws={'color': 'black'})

# %%
sns.boxplot(x='Total Cases', y='Active', data=df_corona, color='yellow')
# Out:
# <AxesSubplot:xlabel='Total Cases', ylabel='Active'>
